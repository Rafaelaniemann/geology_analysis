# %% [markdown]
# # Exemplo: Análise de descontinuidades
# Este notebook carrega um sample e mostra um preview dos dados.

# %%
import pandas as pd
df = pd.read_csv('../data/sample/sample.csv')
df.head()
